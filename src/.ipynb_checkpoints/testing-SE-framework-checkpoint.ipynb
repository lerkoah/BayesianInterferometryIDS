# %%
import numpy as np
import scipy

# %%
n = 512
t = 2.5*np.linspace(-1,1,n)[:,None]
# y = np.sin(10*2*np.pi*t)*(1/(0.5*np.sqrt(2*np.pi)))*np.exp(-(0.5)*np.abs(t)**2/0.5**2)
# y = (1/(0.5*np.sqrt(2*np.pi)))*np.exp(-(0.5)*np.abs(t)**2/0.5**2)
# y = np.where(abs(t)<=0.5, 1, 0)
numberOfBasis = 5

c = [-1, 1, -0.5, 1.2, -1.5]
l = [0.1, 0.2, 0.4, 0.2, 0.2]

y = np.zeros_like(t)
for i in range(numberOfBasis):
    y += 1/(l[i]*np.sqrt(2*np.pi))*np.exp(-(t-c[i])**2/(2*l[i]**2))
#     y += np.exp(-(t-c[i])**2/(2*l[i]**2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(t,y,'.-')

# %%
# f(t) = 1/(l*sqrt(2pi)) exp(-(t-c)**2/(2l**2))
def gaussian_ft(w, l, c):
    return (l*np.sqrt(2*np.pi))/np.sqrt(2*np.pi)*np.exp(-1.0/2.0 *(w*l)**2) * np.exp(1j*c*w)

# %%
from scipy.fftpack import fft
dt = t[1]-t[0]
fs = 1/dt

n_fft = n

f = (fs/2)*np.arange(-1, 1, 2/n_fft)[:,None]
w = np.linspace(-50,50,n_fft)[:,None]
y_fft = np.zeros_like(t, dtype=np.complex128)

# print(y_fft.shape)
for i in range(numberOfBasis):
    y_fft += gaussian_ft(w,l[i],c[i])
y_fft = y_fft.reshape(-1)
# frequencies = np.fft.fftshift(frequencies)[:,None]
# frequencies  = frequencies - np.mean(frequencies)

fig, ax = plt.subplots(1,3, figsize=(17,3))
ax[0].plot(w, y_fft.real, '-')
ax[0].set_xlim([-50,50])
ax[1].plot(w, y_fft.imag, '-')
ax[1].set_xlim([-50,50])
ax[2].plot(w,np.abs(y_fft), '-')
ax[2].set_xlim([-50,50])
# Out:
# (-50, 50)

# %%
np.random.seed(42)

# %%
n_obs = np.ceil(0.4*n_fft).astype('int')
index_obs = np.sort(np.random.choice(np.arange(n_fft), size=n_obs, replace=False))
w_obs = w[index_obs]
y_fft_obs = y_fft[index_obs]
sigma_noise = 0.001
y_fft_obs.real = y_fft_obs.real + sigma_noise*np.random.randn(n_obs)
y_fft_obs.imag = y_fft_obs.imag + sigma_noise*np.random.randn(n_obs)

# %%
fig, ax = plt.subplots(1,3, figsize=(17,3))
ax[0].plot(w_obs, y_fft_obs.real, '.')
# ax[0].set_xlim([-20,20])
ax[1].plot(w_obs, y_fft_obs.imag , '.')
# ax[1].set_xlim([-20,20])
ax[2].plot(w_obs, np.abs(y_fft_obs),'.')
# ax[2].set_xlim([-20,20])

# %%
import gpflow

# %%
isJointcase = True
isNoiseVarianceTrainable = True

# %%
if isJointcase:
    k1 = gpflow.kernels.RBF(1)
#     k1 = gpflow.kernels.Matern12(1)
#     k1 = gpflow.kernels.Matern52(1)
    # k1 = gpflow.kernels.Matern32(1)
#     k3 = gpflow.kernels.Periodic(1)

#     k2 = gpflow.kernels.Cosine(1)
#     k3 = gpflow.kernels.Cosine(1)


    k = gpflow.kernels.RBF(1)*gpflow.kernels.Cosine(1)
    
    for i in range(numberOfBasis-1):
        k += gpflow.kernels.RBF(1)*gpflow.kernels.Cosine(1)
    
    coreg = gpflow.kernels.Coregion(1, output_dim=2, rank=1, active_dims=[1])
    kern = k * coreg
#     #set data dimensions
#     INPUT_DIM = 1
#     N_OUTPUTS = 2
#     #Set the number of components
#     number_of_components = 2
#     kern = MOSM(INPUT_DIM, N_OUTPUTS)
#     for i in range(number_of_components-1):
#         kern += MOSM(INPUT_DIM, N_OUTPUTS)
    
else:
    k1 = gpflow.kernels.Matern12(1)
    # k1 = gpflow.kernels.Matern32(1)
    # k1 = gpflow.kernels.Matern52(1)
    # k1 = gpflow.kernels.RBF(1)
    k2 = gpflow.kernels.Periodic(1)
    kern = k1*k2

# %%
# # k1 = Rectangular()
# k1 = gpflow.kernels.Matern12(1)
# # k1 = gpflow.kernels.Matern32(1)
# # k1 = gpflow.kernels.Matern52(1)
# # k1 = gpflow.kernels.RBF(1)
# k2 = gpflow.kernels.Periodic(1)
# kern = k1*k2

# %%
y_fft_obs.real[:,None].shape
# Out:
# (205, 1)

# %%
if isJointcase:
    X = np.vstack([np.hstack( [w_obs, np.zeros_like(w_obs)] ),
                   np.hstack( [w_obs, np.ones_like(w_obs) ] )])
    Y = np.vstack([np.hstack( [y_fft_obs.real[:,None], np.zeros_like(w_obs)]),
                   np.hstack( [y_fft_obs.imag[:,None], np.ones_like(w_obs)]) ])

else:
    X = w_obs
    Y = y_fft_obs.real[:,None]
print('Y:')
print(Y)

print('X:')
print(X)
# Out:
# Y:
# [[ 2.81351477e-04  0.00000000e+00]
#  [-6.22340888e-04  0.00000000e+00]
#  [-2.07793917e-04  0.00000000e+00]
#  [-4.92806717e-04  0.00000000e+00]
#  [-5.89411995e-04  0.00000000e+00]
#  [ 8.49212345e-04  0.00000000e+00]
#  [ 3.56425598e-04  0.00000000e+00]
#  [-6.93710308e-04  0.00000000e+00]
#  [ 8.98053688e-04  0.00000000e+00]
#  [ 3.05656410e-04  0.00000000e+00]
#  [ 8.11187158e-04  0.00000000e+00]
#  [ 6.28001712e-04  0.00000000e+00]
#  [-8.30481315e-04  0.00000000e+00]
#  [-5.60593736e-04  0.00000000e+00]
#  [ 7.47466373e-04  0.00000000e+00]
#  [ 6.11233837e-04  0.00000000e+00]
#  [-1.92569989e-05  0.00000000e+00]
#  [ 1.19820553e-04  0.00000000e+00]
#  [ 1.28276676e-03  0.00000000e+00]
#  [-5.85728711e-04  0.00000000e+00]
#  [ 5.53527458e-04  0.00000000e+00]
#  [-1.95281305e-04  0.00000000e+00]
#  [-2.14031107e-04  0.00000000e+00]
#  [ 1.09822551e-03  0.00000000e+00]
#  [ 8.15865909e-04  0.00000000e+00]
#  [ 7.94121722e-04  0.00000000e+00]
#  [ 1.28336287e-03  0.00000000e+00]
#  [ 2.25067805e-05  0.00000000e+00]
#  [ 6.93067967e-04  0.00000000e+00]
#  [-2.88485369e-04  0.00000000e+00]
#  [ 3.80380912e-04  0.00000000e+00]
#  [-4.73016601e-05  0.00000000e+00]
#  [ 1.81296446e-04  0.00000000e+00]
#  [ 6.71608250e-04  0.00000000e+00]
#  [-43.9334638    1.        ]
#  [-43.54207436   1.        ]
#  [-42.7592955    1.        ]
#  [-42.36790607   1.        ]
#  [-41.78082192   1.        ]
#  [-41.19373777   1.        ]
#  [-40.99804305   1.        ]
#  [-39.23679061   1.        ]
#  [-39.04109589   1.        ]
#  [-38.84540117   1.        ]
#  [-38.25831703   1.        ]
#  [-37.67123288   1.        ]
#  [-37.08414873   1.        ]
#  [-36.88845401   1.        ]
#  [-36.6927593    1.        ]
#  [-36.49706458   1.        ]
#  [-36.30136986   1.        ]
#  [-35.90998043   1.        ]
#  [-35.71428571   1.        ]
#  [-35.32289628   1.        ]
#  [-35.12720157   1.        ]
#  [-34.93150685   1.        ]
#  [-34.73581213   1.        ]
#  [-34.54011742   1.        ]
#  [-33.95303327   1.        ]
#  [-33.56164384   1.        ]
#  [-33.1702544    1.        ]
#  [-32.38747554   1.        ]
#  [-31.80039139   1.        ]
#  [-31.60469667   1.        ]
#  [-30.23483366   1.        ]
#  [-29.64774951   1.        ]
#  [-28.86497065   1.        ]
#  [-28.47358121   1.        ]
#  [-27.88649706   1.        ]
#  [-27.69080235   1.        ]
#  [-27.29941292   1.        ]
#  [-27.1037182    1.        ]
#  [-26.90802348   1.        ]
#  [-25.73385519   1.        ]
#  [-25.34246575   1.        ]
#  [-24.36399217   1.        ]
#  [-24.16829746   1.        ]
#  [-23.18982387   1.        ]
#  [-22.60273973   1.        ]
#  [-22.40704501   1.        ]
#  [-21.81996086   1.        ]
#  [-21.037182     1.        ]
#  [-20.05870841   1.        ]
#  [-19.8630137    1.        ]
#  [-19.66731898   1.        ]
#  [-19.27592955   1.        ]
#  [-17.31898239   1.        ]
#  [-17.12328767   1.        ]
#  [-16.34050881   1.        ]
#  [-16.14481409   1.        ]
#  [-15.75342466   1.        ]
#  [-15.55772994   1.        ]
#  [-15.36203523   1.        ]
#  [-14.77495108   1.        ]
#  [-14.57925636   1.        ]
#  [-14.38356164   1.        ]
#  [-13.99217221   1.        ]
#  [-13.7964775    1.        ]
#  [-12.42661448   1.        ]
#  [-12.03522505   1.        ]
#  [-11.83953033   1.        ]
#  [-10.2739726    1.        ]
#  [-10.07827789   1.        ]
#  [ -9.29549902   1.        ]
#  [ -9.09980431   1.        ]
#  [ -8.90410959   1.        ]
#  [ -8.70841487   1.        ]
#  [ -7.33855186   1.        ]
#  [ -6.94716243   1.        ]
#  [ -6.55577299   1.        ]
#  [ -5.96868885   1.        ]
#  [ -5.57729941   1.        ]
#  [ -4.79452055   1.        ]
#  [ -4.2074364    1.        ]
#  [ -3.62035225   1.        ]
#  [ -3.42465753   1.        ]
#  [ -2.25048924   1.        ]
#  [ -1.66340509   1.        ]
#  [ -1.27201566   1.        ]
#  [ -1.07632094   1.        ]
#  [ -0.48923679   1.        ]
#  [ -0.09784736   1.        ]
#  [  1.8590998    1.        ]
#  [  2.05479452   1.        ]
#  [  2.44618395   1.        ]
#  [  3.0332681    1.        ]
#  [  3.22896282   1.        ]
#  [  3.62035225   1.        ]
#  [  3.81604697   1.        ]
#  [  4.2074364    1.        ]
#  [  4.40313112   1.        ]
#  [  4.99021526   1.        ]
#  [  5.57729941   1.        ]
#  [  5.96868885   1.        ]
#  [  6.16438356   1.        ]
#  [  6.55577299   1.        ]
#  [  7.92563601   1.        ]
#  [  8.31702544   1.        ]
#  [  8.51272016   1.        ]
#  [  9.09980431   1.        ]
#  [  9.49119374   1.        ]
#  [ 10.86105675   1.        ]
#  [ 11.05675147   1.        ]
#  [ 12.03522505   1.        ]
#  [ 12.23091977   1.        ]
#  [ 12.6223092    1.        ]
#  [ 12.81800391   1.        ]
#  [ 13.20939335   1.        ]
#  [ 13.40508806   1.        ]
#  [ 13.60078278   1.        ]
#  [ 14.38356164   1.        ]
#  [ 14.77495108   1.        ]
#  [ 14.97064579   1.        ]
#  [ 15.36203523   1.        ]
#  [ 16.53620352   1.        ]
#  [ 16.73189824   1.        ]
#  [ 16.92759295   1.        ]
#  [ 18.29745597   1.        ]
#  [ 18.6888454    1.        ]
#  [ 18.88454012   1.        ]
#  [ 19.47162427   1.        ]
#  [ 19.66731898   1.        ]
#  [ 20.45009785   1.        ]
#  [ 20.64579256   1.        ]
#  [ 21.23287671   1.        ]
#  [ 21.42857143   1.        ]
#  [ 22.60273973   1.        ]
#  [ 23.18982387   1.        ]
#  [ 23.58121331   1.        ]
#  [ 24.36399217   1.        ]
#  [ 24.7553816    1.        ]
#  [ 24.95107632   1.        ]
#  [ 26.51663405   1.        ]
#  [ 27.1037182    1.        ]
#  [ 27.29941292   1.        ]
#  [ 27.49510763   1.        ]
#  [ 27.88649706   1.        ]
#  [ 28.86497065   1.        ]
#  [ 29.45205479   1.        ]
#  [ 29.64774951   1.        ]
#  [ 30.23483366   1.        ]
#  [ 31.01761252   1.        ]
#  [ 31.80039139   1.        ]
#  [ 32.19178082   1.        ]
#  [ 32.77886497   1.        ]
#  [ 32.97455969   1.        ]
#  [ 33.95303327   1.        ]
#  [ 34.3444227    1.        ]
#  [ 34.73581213   1.        ]
#  [ 34.93150685   1.        ]
#  [ 35.32289628   1.        ]
#  [ 35.90998043   1.        ]
#  [ 36.10567515   1.        ]
#  [ 36.49706458   1.        ]
#  [ 37.67123288   1.        ]
#  [ 37.86692759   1.        ]
#  [ 38.25831703   1.        ]
#  [ 38.64970646   1.        ]
#  [ 38.84540117   1.        ]
#  [ 39.04109589   1.        ]
#  [ 39.23679061   1.        ]
#  [ 40.4109589    1.        ]
#  [ 40.80234834   1.        ]
#  [ 42.56360078   1.        ]
#  [ 42.7592955    1.        ]
#  [ 43.54207436   1.        ]
#  [ 44.32485323   1.        ]
#  [ 44.52054795   1.        ]
#  [ 44.71624266   1.        ]
#  [ 45.89041096   1.        ]
#  [ 46.08610568   1.        ]
#  [ 46.86888454   1.        ]
#  [ 47.26027397   1.        ]
#  [ 47.65166341   1.        ]
#  [ 48.04305284   1.        ]
#  [ 48.23874755   1.        ]
#  [ 48.43444227   1.        ]
#  [ 49.02152642   1.        ]
#  [ 49.21722114   1.        ]]

# %%
if isJointcase:
    lik = gpflow.likelihoods.SwitchedLikelihood([gpflow.likelihoods.Gaussian(), gpflow.likelihoods.Gaussian()])
else:
    lik = gpflow.likelihoods.Gaussian()

# %%
m = gpflow.models.VGP(X, Y, kern=kern, likelihood=lik, num_latent=1)

if isJointcase:
    m.likelihood.likelihood_list[0].variance = sigma_noise**2
    m.likelihood.likelihood_list[1].variance = sigma_noise**2
    
    if not isNoiseVarianceTrainable:
        m.likelihood.likelihood_list[0].variance.trainable = False
        m.likelihood.likelihood_list[1].variance.trainable = False
else:
    m.likelihood.variance = 1
    
    if not isNoiseVarianceTrainable:
        m.likelihood.variance.trainable = False

opt = gpflow.train.AdamOptimizer()
opt.minimize(m, maxiter=100000)
# Out:
# /home/lerko/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
m.kern.as_pandas_table()
# Out:
#                                                         class prior transform  \
# VGP/kern/kernels/0/kernels/0/kernels/0/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/0/kernels/0/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/0/kernels/1/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/0/kernels/1/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/1/kernels/0/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/1/kernels/0/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/1/kernels/1/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/1/kernels/1/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/2/kernels/0/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/2/kernels/0/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/2/kernels/1/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/2/kernels/1/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/3/kernels/0/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/3/kernels/0/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/3/kernels/1/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/3/kernels/1/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/4/kernels/0/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/4/kernels/0/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/0/kernels/4/kernels/1/variance     Parameter  None       +ve
# VGP/kern/kernels/0/kernels/4/kernels/1/lengthsc...  Parameter  None       +ve
# VGP/kern/kernels/1/W                                Parameter  None    (none)
# VGP/kern/kernels/1/kappa                            Parameter  None       +ve
#
#                                                     trainable   shape  \
# VGP/kern/kernels/0/kernels/0/kernels/0/variance          True      ()
# VGP/kern/kernels/0/kernels/0/kernels/0/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/0/kernels/1/variance          True      ()
# VGP/kern/kernels/0/kernels/0/kernels/1/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/1/kernels/0/variance          True      ()
# VGP/kern/kernels/0/kernels/1/kernels/0/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/1/kernels/1/variance          True      ()
# VGP/kern/kernels/0/kernels/1/kernels/1/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/2/kernels/0/variance          True      ()
# VGP/kern/kernels/0/kernels/2/kernels/0/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/2/kernels/1/variance          True      ()
# VGP/kern/kernels/0/kernels/2/kernels/1/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/3/kernels/0/variance          True      ()
# VGP/kern/kernels/0/kernels/3/kernels/0/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/3/kernels/1/variance          True      ()
# VGP/kern/kernels/0/kernels/3/kernels/1/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/4/kernels/0/variance          True      ()
# VGP/kern/kernels/0/kernels/4/kernels/0/lengthsc...       True      ()
# VGP/kern/kernels/0/kernels/4/kernels/1/variance          True      ()
# VGP/kern/kernels/0/kernels/4/kernels/1/lengthsc...       True      ()
# VGP/kern/kernels/1/W                                     True  (2, 1)
# VGP/kern/kernels/1/kappa                                 True    (2,)
#
#                                                     fixed_shape  \
# VGP/kern/kernels/0/kernels/0/kernels/0/variance            True
# VGP/kern/kernels/0/kernels/0/kernels/0/lengthsc...         True
# VGP/kern/kernels/0/kernels/0/kernels/1/variance            True
# VGP/kern/kernels/0/kernels/0/kernels/1/lengthsc...         True
# VGP/kern/kernels/0/kernels/1/kernels/0/variance            True
# VGP/kern/kernels/0/kernels/1/kernels/0/lengthsc...         True
# VGP/kern/kernels/0/kernels/1/kernels/1/variance            True
# VGP/kern/kernels/0/kernels/1/kernels/1/lengthsc...         True
# VGP/kern/kernels/0/kernels/2/kernels/0/variance            True
# VGP/kern/kernels/0/kernels/2/kernels/0/lengthsc...         True
# VGP/kern/kernels/0/kernels/2/kernels/1/variance            True
# VGP/kern/kernels/0/kernels/2/kernels/1/lengthsc...         True
# VGP/kern/kernels/0/kernels/3/kernels/0/variance            True
# VGP/kern/kernels/0/kernels/3/kernels/0/lengthsc...         True
# VGP/kern/kernels/0/kernels/3/kernels/1/variance            True
# VGP/kern/kernels/0/kernels/3/kernels/1/lengthsc...         True
# VGP/kern/kernels/0/kernels/4/kernels/0/variance            True
# VGP/kern/kernels/0/kernels/4/kernels/0/lengthsc...         True
# VGP/kern/kernels/0/kernels/4/kernels/1/variance            True
# VGP/kern/kernels/0/kernels/4/kernels/1/lengthsc...         True
# VGP/kern/kernels/1/W                                       True
# VGP/kern/kernels/1/kappa                                   True
#
#                                                                                          value
# VGP/kern/kernels/0/kernels/0/kernels/0/variance                            0.15892904311128167
# VGP/kern/kernels/0/kernels/0/kernels/0/lengthsc...                          3.2394155459207052
# VGP/kern/kernels/0/kernels/0/kernels/1/variance                             0.1589290431086946
# VGP/kern/kernels/0/kernels/0/kernels/1/lengthsc...                          1.1276544831200346
# VGP/kern/kernels/0/kernels/1/kernels/0/variance                            0.15892904311128167
# VGP/kern/kernels/0/kernels/1/kernels/0/lengthsc...                          3.2394155459207052
# VGP/kern/kernels/0/kernels/1/kernels/1/variance                             0.1589290431086946
# VGP/kern/kernels/0/kernels/1/kernels/1/lengthsc...                          1.1276544831200346
# VGP/kern/kernels/0/kernels/2/kernels/0/variance                            0.15892904311128167
# VGP/kern/kernels/0/kernels/2/kernels/0/lengthsc...                          3.2394155459207052
# VGP/kern/kernels/0/kernels/2/kernels/1/variance                             0.1589290431086946
# VGP/kern/kernels/0/kernels/2/kernels/1/lengthsc...                          1.1276544831200346
# VGP/kern/kernels/0/kernels/3/kernels/0/variance                            0.15892904311128167
# VGP/kern/kernels/0/kernels/3/kernels/0/lengthsc...                          3.2394155459207052
# VGP/kern/kernels/0/kernels/3/kernels/1/variance                             0.1589290431086946
# VGP/kern/kernels/0/kernels/3/kernels/1/lengthsc...                          1.1276544831200346
# VGP/kern/kernels/0/kernels/4/kernels/0/variance                            0.15892904311128167
# VGP/kern/kernels/0/kernels/4/kernels/0/lengthsc...                          3.2394155459207052
# VGP/kern/kernels/0/kernels/4/kernels/1/variance                             0.1589290431086946
# VGP/kern/kernels/0/kernels/4/kernels/1/lengthsc...                          1.1276544831200346
# VGP/kern/kernels/1/W                                                            [[0.0], [0.0]]
# VGP/kern/kernels/1/kappa                            [0.23213083186211758, 0.06999422080731428]

# %%
# m.kern.kernels[0].lengthscales

# %%
m.likelihood.as_pandas_table()
# Out:
#                                                class prior transform  \
# VGP/likelihood/likelihood_list/0/variance  Parameter  None       +ve
# VGP/likelihood/likelihood_list/1/variance  Parameter  None       +ve
#
#                                            trainable shape  fixed_shape  \
# VGP/likelihood/likelihood_list/0/variance       True    ()         True
# VGP/likelihood/likelihood_list/1/variance       True    ()         True
#
#                                                             value
# VGP/likelihood/likelihood_list/0/variance   1.000000002220446e-06
# VGP/likelihood/likelihood_list/1/variance  1.0000000005065892e-06

# %%
def plot_gp(x, mu, var, color='k', ax = None):
    ax.plot(x, mu, '+', color=color, lw=2)
    
    lower_bound = mu - 2*np.sqrt(var)
    upper_bound = mu + 2*np.sqrt(var)
    print(x.shape)
    print(lower_bound.shape)
    print(upper_bound.shape)
    ax.fill_between(x.reshape(-1), lower_bound[:,0].reshape(-1), upper_bound[:,0].reshape(-1) , color=color, alpha=0.3)

def plot(mu, var, X = w_obs, Y = y_fft_obs.real, fig=None , ax=None, str_title=None): 
    line, = ax.plot(X, Y, 'x', mew=2)
    plot_gp(w, mu, var, line.get_color(), ax=ax)
    
    if not str_title is None:
        ax.set_title(str_title)
    ax.legend(['Real spectrum', 'Observation', 'Estimation'])

# %%
fig = plt.figure(figsize=(17,5))
ax = fig.add_subplot(211)
x1_augmented = np.hstack( [w, np.zeros_like(f)] )
mu_real, var_real = m.predict_f(x1_augmented)

plt.plot(w, y_fft.real, '.r', mew=2)
plot(mu_real,var_real, Y=y_fft_obs.real, fig=fig, ax=ax, str_title='Real Part')
ax.set_xlim([-50,50])

ax = fig.add_subplot(212)
x2_augmented = np.hstack( [w, np.ones_like(f)] )
mu_imag, var_imag = m.predict_f(x2_augmented)

plt.plot(w, y_fft.imag, '.r', mew=2)
plot(mu_imag,var_imag, Y = y_fft_obs.imag, fig=fig, ax=ax, str_title='Imaginary Part')
ax.set_xlim([-50,50])
fig.tight_layout()
# fig.savefig('spectrum.pdf', format='pdf')
# Out:
# (512, 1)
# (512, 1)
# (512, 1)
# (512, 1)
# (512, 1)
# (512, 1)

# %%
import scipy as sp

# %%
F = sp.linalg.dft(n)
invF = sp.linalg.inv(F)

# %%
x_augmented = np.concatenate((x1_augmented,x2_augmented))
x_augmented.shape
numberOfSamplings = 20
S_ft_all= m.predict_f_samples(x_augmented,numberOfSamplings)
S_ft = S_ft_all[:,:512,:]+1j*S_ft_all[:,512:,:]
S = np.abs(np.matmul(invF,S_ft[:,:,:]))

# %%
mu = mu_real+1j*mu_imag
fig = plt.figure(figsize=(17,6))
ax = plt.subplot(211)
y_hat = np.abs(np.matmul(invF,mu))
y_real = np.abs(np.matmul(invF,y_fft))
# y_real = np.matmul(invF,y_fft).real
# ax.plot(t,y_real,'-',  linewidth=2, label='Real signal' , markersize=2)
for i in range(numberOfSamplings):
    ax.plot(t, S[i,:,:],'r', linewidth = 0.7, alpha=0.4)
ax.plot(t, S[0,:,:],'r', linewidth = 0.7, alpha=1, label='Samplings')
ax.plot(t,y_hat,'-', color='royalblue', linewidth=1, label='Estimation', markersize=2)
# ax.plot(t,y_real, label='Real Signal')
ax.legend()


# ax.set_xlim([-1.5,-1])
# plt.plot(t,S, alpha=0.3)
# plt.fill_between(t.reshape(-1), y_hat.reshape(-1), y_hat.reshape(-1)+2*np.sqrt(var_hat), y_hat.reshape(-1)-2*np.sqrt(var_hat), alpha=0.3)
ax = plt.subplot(212)
# ax.plot(t,y/250, label='Real Signal')
ax.plot(t,y_real, label='Inverse Fourier Signal')
ax.legend()
fig.tight_layout()
fig.savefig('GP-spectrum-reconstruction.pdf', format='pdf')
